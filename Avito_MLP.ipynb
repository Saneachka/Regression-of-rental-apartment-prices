# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import RandomizedSearchCV
import pickle
from tensorflow.keras.models import load_model
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.losses import Huber
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ### Работа с данными

# %%
xl = pd.read_excel('Avito House.xlsx')

# %%
df = pd.DataFrame(xl)

# %%
df
# Out:
#                              Название   Цена  \
# 0      1-к. квартира, 45 м², 3/17 эт.  30000
# 1     1-к. квартира, 38 м², 10/23 эт.  40000
# 2    Квартира-студия, 42 м², 3/10 эт.  25000
# 3       2-к. квартира, 65 м², 7/9 эт.  37000
# 4      2-к. квартира, 68 м², 7/10 эт.  35000
# ..                                ...    ...
# 739     2-к. квартира, 50 м², 2/2 эт.  35000
# 740   1-к. квартира, 52 м², 11/24 эт.  38000
# 741     3-к. квартира, 54 м², 2/2 эт.  35000
# 742     1-к. квартира, 34 м², 2/8 эт.  25000
# 743     2-к. квартира, 55 м², 1/3 эт.  25000
#
#                                                                                                                                                                       URL  \
# 0                                                                                      https://www.avito.ru/rostov-na-donu/kvartiry/1-k._kvartira_45_m_317_et._4608266976
# 1                                                                                     https://www.avito.ru/rostov-na-donu/kvartiry/1-k._kvartira_38_m_1023_et._4392910511
# 2                                                                                   https://www.avito.ru/rostov-na-donu/kvartiry/kvartira-studiya_42_m_310_et._4727843608
# 3                                                                                       https://www.avito.ru/rostov-na-donu/kvartiry/2-k._kvartira_65_m_79_et._2228490799
# 4                                                                                      https://www.avito.ru/rostov-na-donu/kvartiry/2-k._kvartira_68_m_710_et._3816284415
# ..                                                                                                                                                                    ...
# 739    https://www.avito.ru/rostov-na-donu/kvartiry/2-k._kvartira_50_m_22_et._3513447963?context=H4sIAAAAAAAA_wEfAOD_YToxOntzOjEzOiJsb2NhbFByaW9yaXR5IjtiOjA7fQseF2QfAAAA
# 740  https://www.avito.ru/rostov-na-donu/kvartiry/1-k._kvartira_52_m_1124_et._4582523363?context=H4sIAAAAAAAA_wEfAOD_YToxOntzOjEzOiJsb2NhbFByaW9yaXR5IjtiOjA7fQseF2QfAAAA
# 741    https://www.avito.ru/rostov-na-donu/kvartiry/3-k._kvartira_54_m_22_et._4707633091?context=H4sIAAAAAAAA_wEfAOD_YToxOntzOjEzOiJsb2NhbFByaW9yaXR5IjtiOjA7fQseF2QfAAAA
# 742    https://www.avito.ru/rostov-na-donu/kvartiry/1-k._kvartira_34_m_28_et._2730382363?context=H4sIAAAAAAAA_wEfAOD_YToxOntzOjEzOiJsb2NhbFByaW9yaXR5IjtiOjA7fQseF2QfAAAA
# 743    https://www.avito.ru/rostov-na-donu/kvartiry/2-k._kvartira_55_m_13_et._4540184835?context=H4sIAAAAAAAA_wEfAOD_YToxOntzOjEzOiJsb2NhbFByaW9yaXR5IjtiOjA7fQseF2QfAAAA
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Описание  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
# 3       ростовская обл., ростов-на-дону, пр-т 40-летия победы, 13/9\nр-н пролетарский
# 4                ростовская обл., ростов-на-дону, ул. миронова, 14а\nр-н первомайский
# ..                                                                                ...
# 739                  ростовская обл., ростов-на-дону, ул. баумана, 35а\nр-н ленинский
# 740         ростовская обл., ростов-на-дону, берберовская ул., 28с1\nр-н пролетарский
# 741               ростовская обл., ростов-на-дону, пер. семашко, 22/92\nр-н ленинский
# 742          ростовская обл., ростов-на-дону, б-р платова, 20/17\nр-н железнодорожный
# 743         ростовская обл., ростов-на-дону, днепровский пер., 131г\nр-н первомайский
#
# [744 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Название         744 non-null    object
#  1   Цена             744 non-null    int64
#  2   URL              744 non-null    object
#  3   Описание         744 non-null    object
#  4   Просмотров       744 non-null    int64
#  5   Дата публикации  744 non-null    datetime64[ns]
#  6   Продавец         744 non-null    object
#  7   Адрес            744 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 46.6+ KB

# %%
#Добавляем столбец Площадь с данными о ней
df ['Площадь'] = df['Название'].str.extract(r'(\d+)\s*м²')[0].astype('int32')

# %%
#Добавляем столбец Кол-во комнат с данными о ней
df['Количество комнат'] = df['Название'].str[0]

# %%
#Изменяем данные в 'Количество комнат' где К на 0 - это студии
df.loc[df['Количество комнат'] == 'К', 'Количество комнат'] = 0

# %%
# Преобразовываем в числовой тип
df["Количество комнат"] = df['Количество комнат'].astype('int32')

# %%
df['Количество комнат'].unique()
# Out:
# array([1, 0, 2, 4, 3], dtype=int32)

# %%
# Добавляем столбец этаж с данными о ней
df['Этаж'] = df['Название'].str.extract(r'\b(\d+)/').astype('int32')

# %%
# Добавляем столбец Всего этажей с данными о ней
df['Всего этажей'] = df['Название'].str.extract(r'\b/(\d+)').astype('int32')

# %%
df.head(5)
# Out:
#                            Название   Цена  \
# 0    1-к. квартира, 45 м², 3/17 эт.  30000
# 1   1-к. квартира, 38 м², 10/23 эт.  40000
# 2  Квартира-студия, 42 м², 3/10 эт.  25000
# 3     2-к. квартира, 65 м², 7/9 эт.  37000
# 4    2-к. квартира, 68 м², 7/10 эт.  35000
#
#                                                                                      URL  \
# 0     https://www.avito.ru/rostov-na-donu/kvartiry/1-k._kvartira_45_m_317_et._4608266976
# 1    https://www.avito.ru/rostov-na-donu/kvartiry/1-k._kvartira_38_m_1023_et._4392910511
# 2  https://www.avito.ru/rostov-na-donu/kvartiry/kvartira-studiya_42_m_310_et._4727843608
# 3      https://www.avito.ru/rostov-na-donu/kvartiry/2-k._kvartira_65_m_79_et._2228490799
# 4     https://www.avito.ru/rostov-na-donu/kvartiry/2-k._kvartira_68_m_710_et._3816284415
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Описание  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Очень уютная 1-к квартира от собственника в ЖК Сокол град. Закрытая охраняемая территория, огромная детская площадка во дворе. Квартира новая в ней, практически никто не жил.
# 1  * от Собственника*. Прекрасная квартира для тех, кто ценит комфорт и красоту. *Уютный интерьер* — эта квартира создана для людей, которые любят себя и окружающую красоту. Здесь гармонично сочетаются стиль и функциональность, что делает её идеальным местом для проживания. *Панорамный балкон* — наслаждайтесь завтраком или вечерним чаем на балконе с потрясающим видом на живописную аллею. *Комфорт в любые времена года* — два кондиционера: в кухне и комнате обеспечат идеальную атмосферу. Индивидуальное отопление гарантирует теплые зимние вечера, при этом расходы на отопление вас приятно удивят. *Функциональные зоны* — квартира предлагает удобные пространства, включая зону отдыха: кровать с ортопедическим матрасом Ikea, где вы сможете расслабиться после долгого дня, и уютную зону с телевизором для приятных вечеров с любимыми фильмами. Максимальная вместимость два человека. *Минимальные коммунальные платежи* — вы сможете наслаждаться комфортом и практичностью, не беспокоясь о высоких счетах. Всё в этой квартире сделано эргономично. *Фотографии квартиры* полностью соответствуют действительности, чтобы вы могли насладиться её уникальным стилем до первого визита. Российское гражданство, прописка РФ. Без детей. Без животных. Запрещено курить. Субаренда.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           При встрече расскажу.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Объявление реальное, я собственник. Сдаётся двухкомнатная уютная квартира в элитном ЖК «Голубые ели». Дома в комплексе 9 этажей. Охраняемая закрытая территория, видеонаблюдение, консьерж, собственная парковка. Детские и спортивные площадки, зоны отдыха, магазины, парикмахерские, спортивный центр, дет. Сады и т. Д. В шаговой доступности школы, общественный транспорт и вся инфраструктура. В квартире есть всё необходимое для жизни -мебель и бытовая техника. Просторная лоджия, окна выходят во двор. Собственник, без посредников.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Заходите и живите.
#
#    Просмотров Дата публикации      Продавец  \
# 0         170      2025-01-23  Арендодатель
# 1        1583      2025-01-14  Арендодатель
# 2         430      2025-01-21  Арендодатель
# 3        3060      2025-01-20  Арендодатель
# 4         334      2025-01-18  Арендодатель
#
#                                                                               Адрес  \
# 0  ростовская обл., ростов-на-дону, пр-т 40-летия победы, 63/17с7\nр-н пролетарский
# 1         ростовская обл., ростов-на-дону, берберовская ул., 16с2\nр-н пролетарский
# 2            ростовская обл., ростов-на-дону, ул. 2-й пятилетки, 6\nр-н октябрьский
# 3     ростовская обл., ростов-на-дону, пр-т 40-летия победы, 13/9\nр-н пролетарский
# 4              ростовская обл., ростов-на-дону, ул. миронова, 14а\nр-н первомайский
#
#    Площадь  Количество комнат  Этаж  Всего этажей
# 0       45                  1     3            17
# 1       38                  1    10            23
# 2       42                  0     3            10
# 3       65                  2     7             9
# 4       68                  2     7            10

# %%
#Преобразовываем типы данных 
df['Продавец'] = df['Продавец'].astype('category')

# %%
#Cоздаем новый столбец с типом квартиры
df['Тип'] = df['Количество комнат'].map({0: 'Студия', 1 : 'Квартира', 2 : 'Квартира', 3 : 'Квартира', 4 : 'Квартира'}).astype('category')

# %%
pd.options.display.max_colwidth = None
df['Адрес'][100:130]
# Out:
# 100                                   ростовская обл., ростов-на-дону, ул. серафимовича, 37\nр-н ленинский
# 101                                ростовская обл., ростов-на-дону, пер. поленова, 21/10\nр-н первомайский
# 102                                         ростовская обл., ростов-на-дону, ул. седова, 63\nр-н кировский
# 103                                   ростовская обл., ростов-на-дону, пер. белоусова, 20\nр-н октябрьский
# 104                                  ростовская обл., ростов-на-дону, пр-т шолохова, 264\nр-н первомайский
# 105                                      ростовская обл., ростов-на-дону, ул. ерёменко, 112\nр-н советский
# 106               ростовская обл., ростов-на-дону, мкр-н северный, пр-т космонавтов, 20\nр-н ворошиловский
# 107                            ростовская обл., ростов-на-дону, ул. петрашевского, 36\nр-н железнодорожный
# 108                                        ростовская обл., ростов-на-дону, ул. зорге, 56/2\nр-н советский
# 109                           ростовская обл., ростов-на-дону, 1-я баррикадная ул., 3\nр-н железнодорожный
# 110                            ростовская обл., ростов-на-дону, пр-т 40-летия победы, 21\nр-н пролетарский
# 111                                    ростовская обл., ростов-на-дону, ул. ерёменко, 90/27\nр-н советский
# 112                                   ростовская обл., ростов-на-дону, ул. миронова, 3/3\nр-н первомайский
# 113                           ростовская обл., ростов-на-дону, западный, ул. жмайлова, 23/2\nр-н советский
# 114                               ростовская обл., ростов-на-дону, пр-т солженицына, 15/1с2\nр-н советский
# 115                          ростовская обл., ростов-на-дону, 1-я баррикадная ул., 48\nр-н железнодорожный
# 116                           ростовская обл., ростов-на-дону, пр-т 40-летия победы, 310\nр-н пролетарский
# 117                                       ростовская обл., ростов-на-дону, пр-т стачки, 218\nр-н советский
# 118                                     ростовская обл., ростов-на-дону, ул. петренко, 14\nр-н октябрьский
# 119          ростовская обл., ростов-на-дону, мкр-н новое поселение, гвардейский пер., 11/2\nр-н ленинский
# 120                    ростовская обл., ростов-на-дону, мкр-н северный, ул. беляева, 28\nр-н ворошиловский
# 121              ростовская обл., ростов-на-дону, мкр-н северный, пр-т космонавтов, 8/3\nр-н ворошиловский
# 122                                      ростовская обл., ростов-на-дону, ул. ерёменко, 112\nр-н советский
# 123    ростовская обл., ростов-на-дону, первомайский район, 2-я производственная ул., 26\nр-н первомайский
# 124                                     ростовская обл., ростов-на-дону, пер. андреева, 7\nр-н октябрьский
# 125                                   ростовская обл., ростов-на-дону, ул. миронова, 4/1\nр-н первомайский
# 126                  ростовская обл., ростов-на-дону, мкр-н северный, творческая ул., 5\nр-н ворошиловский
# 127                                 ростовская обл., ростов-на-дону, пушкинская ул., 176/91\nр-н кировский
# 128                  ростовская обл., ростов-на-дону, мкр-н северный, ул. волкова, 41/2\nр-н ворошиловский
# 129                               ростовская обл., ростов-на-дону, ул. дмитрия петрова, 8\nр-н октябрьский
# Name: Адрес, dtype: object

# %%
#Создаем столбец улица 
df['Улица'] = df['Адрес'].str.extract(r'((?:пр-т|пл.?|ул\.?|пер\.?|б-р)\s[^\n,]+|[^\n,]+\s(?:пр-т|пл.?|ул\.?|пер\.?|б-р))')

# %%
#Проверяем новый столбец на null
pd.options.display.max_colwidth = None
df[df['Улица'].isna()][['Адрес','Улица']]
# Out:
#                                                                                            Адрес  \
# 421                              ростовская обл., ростов-на-дону, кировский район\nр-н кировский
# 457  ростовская обл., ростов-на-дону, кировский район, жилой комплекс ростов-сити\nр-н кировский
#
#     Улица
# 421   NaN
# 457   NaN

# %%
# Заменяем в ручную nan значения
df['Улица'].iloc[421] = 'Unknown'
df['Улица'].iloc[457] = 'ул. Суворова'
# Out:
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\613182292.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Улица'].iloc[421] = 'Unknown'
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\613182292.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Улица'].iloc[421] = 'Unknown'
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\613182292.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Улица'].iloc[457] = 'ул. Суворова'
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\613182292.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Улица'].iloc[457] = 'ул. Суворова'

# %%
# Cоздаем столбец номера домов
df['Номер дома'] = df['Адрес'].str.extract(r'(\d+(?:/\d+)*[а-яА-Я\d]*)')

# %%
#Проверяем Номер дома столбец на null
df[df['Номер дома'].isna()][['Адрес','Номер дома']]
# Out:
#                                                                                            Адрес  \
# 375                            ростовская обл., ростов-на-дону, халтуринский пер.\nр-н ленинский
# 421                              ростовская обл., ростов-на-дону, кировский район\nр-н кировский
# 451                          ростовская обл., ростов-на-дону, большая садовая ул.\nр-н ленинский
# 457  ростовская обл., ростов-на-дону, кировский район, жилой комплекс ростов-сити\nр-н кировский
#
#     Номер дома
# 375        NaN
# 421        NaN
# 451        NaN
# 457        NaN

# %%
# Заменяем в ручную nan значения
df['Номер дома'].iloc[457] = 91
df['Номер дома'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\1636728407.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Номер дома'].iloc[457] = 91
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\1636728407.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Номер дома'].iloc[457] = 91
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\1636728407.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Номер дома'].fillna('Unknown', inplace=True)

# %%
# Cоздаем столбец район
df['Район'] = df['Адрес'].str.extract(r'р-н\s([а-яА-Я\s]+)')

# %%
df['Район'].unique()
# Out:
# array(['пролетарский', 'октябрьский', 'первомайский', 'ленинский',
#        'кировский', 'железнодорожный', 'северный', 'советский',
#        'ленгородок', 'западный', 'сельмаш', 'ворошиловский',
#        'новое поселение', 'темерник', 'мясникован', 'болгарстрой',
#        'берберовка', 'каменка'], dtype=object)

# %%
#Проверяем Район столбец на null
df[df['Район'].isna()][['Адрес','Номер дома']]
# Out:
# Empty DataFrame
# Columns: [Адрес, Номер дома]
# Index: []

# %%
#Удаляем не нужные столбцы 
df.drop(columns=['Описание', 'Название', 'URL', 'Адрес'], inplace=True)

# %%
#Преобразовываем типы данных 
df['Район'] = df['Район'].astype('category')
df['Улица'] = df['Улица'].astype('string')
df['Номер дома'] = df['Номер дома'].astype('string')

# %%
#Преобразовываем данные к одному виду. Чтобы ул. была в начали 
df['Улица'] = df['Улица'].str.replace(r'(\S+)\sпер\.$', r'пер. \1', regex=True)
df['Улица'] = df['Улица'].str.replace(r'(\S+)\sул\.$', r'ул. \1', regex=True)
df['Улица'] = df['Улица'].str.replace(r'(\S+)\sб-р\.$', r'б-р. \1', regex=True)
df['Улица'] = df['Улица'].str.replace(r'(\S+)\sпл\.$', r'пл. \1', regex=True)
df['Улица'] = df['Улица'].str.replace(r'(\S+)\sпр-т\.$', r'пр-т. \1', regex=True)

# %%
#Ставим . в конце сокращений
df['Улица'] = df['Улица'].str.replace(r'\bпер\s(?!\.)', r'пер. ', regex=True)
df['Улица'] = df['Улица'].str.replace(r'\bул\s(?!\.)', r'ул. ', regex=True)
df['Улица'] = df['Улица'].str.replace(r'\bпл\s(?!\.)', r'пл. ', regex=True)
df['Улица'] = df['Улица'].str.replace(r'\bпр-т\s(?!\.)', r'пр-т. ', regex=True)
df['Улица'] = df['Улица'].str.replace(r'\bб-р\s(?!\.)', r'б-р. ', regex=True)

#пр-т без . перобразовываем в пр-т. И б-р.
df['Улица'] = df['Улица'].str.replace(r'(\S+)\sпр-т$', r'пр-т. \1', regex=True)
df['Улица'] = df['Улица'].str.replace(r'(\S+)\sб-р$', r'б-р. \1', regex=True)

# %%
#Перемещаем из середины в начало
df['Улица'] = df['Улица'].str.replace(r'(\S+)\sул\.\s(\S+)', r'ул. \1 \2', regex=True)
df['Улица'] = df['Улица'].str.replace(r'(\S+)\sпер\.\s(\S+)', r'пер. \1 \2', regex=True)

# %%
#Проверяем что все строки соответствуют данному условию. 
#Просмотр строк, не начинающихся с указанных аббревиатур с точкой
df[~df['Улица'].str.contains(r'^пер\.|^ул\.|^пл\.|^пр-т\.|^б-р\.')]
# Out:
#       Цена  Просмотров Дата публикации      Продавец  Площадь  \
# 1    40000        1583      2025-01-14  Арендодатель       38
# 6    38000        1963      2025-01-21     Агентство       36
# 7    45000         130      2025-01-23     Агентство       75
# 8    35000         982      2025-01-23     Агентство       32
# 9    30000         924      2025-01-21  Арендодатель       33
# ..     ...         ...             ...           ...      ...
# 734  26000         489      2025-01-20  Арендодатель       42
# 737  20000          10      2025-01-26       Риелтор       40
# 740  38000          24      2025-01-26  Арендодатель       52
# 742  25000         283      2025-01-26  Арендодатель       34
# 743  25000         743      2025-01-26     Агентство       55
#
#      Количество комнат  Этаж  Всего этажей       Тип                 Улица  \
# 1                    1    10            23  Квартира      ул. берберовская
# 6                    1     7            26  Квартира         пер. соборный
# 7                    2     7            10  Квартира     ул. искусственная
# 8                    1    15            24  Квартира      ул. берберовская
# 9                    0     2             4    Студия   пер. педагогический
# ..                 ...   ...           ...       ...                   ...
# 734                  1    17            17  Квартира        ул. стабильная
# 737                  1    10            10  Квартира      пер. днепровский
# 740                  1    11            24  Квартира      ул. берберовская
# 742                  1     2             8  Квартира              б-р. пла
# 743                  2     1             3  Квартира      пер. днепровский
#
#     Номер дома            Район
# 1         16с2     пролетарский
# 6           98      октябрьский
# 7            4     пролетарский
# 8           30     пролетарский
# 9            6      октябрьский
# ..         ...              ...
# 734         21        советский
# 737       116в     первомайский
# 740       28с1     пролетарский
# 742      20/17  железнодорожный
# 743       131г     первомайский
#
# [253 rows x 12 columns]

# %%
#Убираем пробелы в начале 
df['Улица'] = df['Улица'].str.replace(r'^\s+', '', regex=True)

# %%
df['Улица'].str.contains(r'^Unk|^пер\.|^ул\.|^пл\.|^пр-т\.|^б-р\.').sum()
# Out:
# np.int64(744)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Цена, Просмотров, Дата публикации, Продавец, Площадь, Количество комнат, Этаж, Всего этажей, Тип, Улица, Номер дома, Район]
# Index: []

# %%
df.drop(index=98, inplace=True)

# %%
df.drop(df[df['Площадь'] == 120].index, inplace=True)

# %% [markdown]
# ### Визуализация

# %%
#Статистика числовых данных
df.describe()
# Out:
#                 Цена    Просмотров                Дата публикации     Площадь  \
# count     740.000000    740.000000                            740  740.000000
# mean    28315.782432   1131.471622  2024-11-18 16:09:04.864864768   39.205405
# min     12000.000000      0.000000            1900-01-19 00:00:00    1.000000
# 25%     22000.000000    220.500000            2025-01-16 00:00:00   30.000000
# 50%     26000.000000    539.500000            2025-01-20 00:00:00   38.000000
# 75%     32000.000000   1265.250000            2025-01-24 00:00:00   47.250000
# max    170000.000000  16138.000000            2025-01-26 00:00:00  110.000000
# std     11397.991445   1804.040596                            NaN   16.654605
#
#        Количество комнат        Этаж  Всего этажей
# count         740.000000  740.000000    740.000000
# mean            1.255405    7.156757     13.687838
# min             0.000000    1.000000      1.000000
# 25%             1.000000    3.000000      8.000000
# 50%             1.000000    5.000000     14.000000
# 75%             2.000000   10.000000     19.000000
# max             4.000000   26.000000     27.000000
# std             0.818203    5.344153      7.190515

# %%
#Статистика числовых данных с фильтром по районам(первомайский', 'сельмаш) и типу жилья(Студия) 
df[(df['Район'].isin(['первомайский', 'сельмаш'])) & (df['Тип'] == 'Студия')].describe()
# Out:
#                Цена   Просмотров                Дата публикации    Площадь  \
# count     13.000000    13.000000                             13  13.000000
# mean   19076.923077  1346.923077  2025-01-17 18:27:41.538461440  27.076923
# min    13000.000000    60.000000            2025-01-09 00:00:00  21.000000
# 25%    17000.000000   352.000000            2025-01-14 00:00:00  25.000000
# 50%    18000.000000   956.000000            2025-01-19 00:00:00  27.000000
# 75%    23000.000000  1587.000000            2025-01-20 00:00:00  30.000000
# max    25000.000000  4309.000000            2025-01-26 00:00:00  34.000000
# std     4091.893174  1287.476243                            NaN   3.684688
#
#        Количество комнат       Этаж  Всего этажей
# count               13.0  13.000000     13.000000
# mean                 0.0   7.461538     13.076923
# min                  0.0   1.000000      1.000000
# 25%                  0.0   4.000000      6.000000
# 50%                  0.0   6.000000     16.000000
# 75%                  0.0  10.000000     18.000000
# max                  0.0  24.000000     24.000000
# std                  0.0   6.514284      7.878891

# %%
#Копируем датафрейм для удобства работы в дальнейшем
df_Rostov = df.copy()

# %%
#Преобразовываем каиегории в численные форматы
df_Rostov['Продавец'] = df_Rostov['Продавец'].map({'Агентство' : 0, 'Риелтор' : 0, 'Арендодатель': 1})
df_Rostov['Тип'] = df_Rostov['Тип'].map({'Квартира': 1, 'Студия': 0})

# %%
#График средней стоимости цены по районам
plt.figure(figsize=(16,8))
sns.barplot(data=df_Rostov, x = 'Район', y = 'Цена', dodge=False)
plt.title('Средняя стоимость в зависимости от района')
plt.xticks(rotation=45)
plt.show()

# %%
df_cor = df_Rostov.copy()
df_cor.drop(columns=['Номер дома', 'Улица', 'Район'], inplace=True)

plt.figure(figsize=(16,8))
sns.heatmap(data= df_cor.corr(method = 'kendall').round(2), annot= True, cmap="coolwarm")
plt.title('Tепловая карта корреляций')
# Out:
# Text(0.5, 1.0, 'Tепловая карта корреляций')

# %%
# Столбчатая диаграмма y =цен, x = дата сгрупированных по типу 'Студия' продавец 'Арендадатель'
data_filter = df_Rostov.loc[(df_Rostov['Тип'] == 0) & (df_Rostov['Продавец'] == 1), ['Цена', 'Дата публикации']] 

mean_price = np.mean(data_filter['Цена'])
median_price = np.median(data_filter['Цена'])

plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.barplot(data= data_filter, x = 'Дата публикации', y = 'Цена', palette='pastel')
plt.axhline(mean_price, linestyle = '--', color = 'red')
plt.axhline(median_price, linestyle = '-', color = 'purple')
plt.title('Стоимость на студии в Ростове-на-Дону от собственника',fontsize=20)
plt.figtext(0.49, 0.61, f"Средняя цена: {mean_price:.2f}", color='red', fontsize=13, ha='center')
plt.figtext(0.49, 0.56, f"Медианная цена: {median_price:.2f}", color='purple', fontsize=13, ha='center')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\3777945388.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= data_filter, x = 'Дата публикации', y = 'Цена', palette='pastel')

# %%
df_Rostov.loc[(df_Rostov['Тип'] == 0) & (df_Rostov['Продавец'] == 1)].mode()
# Out:
#       Цена  Просмотров Дата публикации  Продавец  Площадь  Количество комнат  \
# 0  30000.0       430.0      2025-01-25       1.0     30.0                0.0
# 1      NaN         NaN             NaT       NaN      NaN                NaN
#
#    Этаж  Всего этажей  Тип        Улица Номер дома        Район
# 0     1          18.0    0  ул. нансена          7  октябрьский
# 1     2           NaN  NaN         <NA>          9          NaN

# %%
data_filter = df_Rostov[['Цена', 'Площадь']].sort_values(by='Площадь')

# %%
# Столбчатая диаграмма y =цен, x = площадь

mean_price = np.mean(data_filter['Цена'])
median_price = np.median(data_filter['Цена'])

plt.figure(figsize=(16,8))
sns.set_style("whitegrid")
sns.lineplot(data= data_filter, x = 'Площадь', y = 'Цена', palette='pastel')
plt.axhline(mean_price, linestyle = '--', color = 'red')
plt.axhline(median_price, linestyle = '-', color = 'purple')
plt.title('Стоимость жилья в Ростове-на-Дону в зависимости от площади',fontsize=20)
plt.figtext(0.49, 0.61, f"Средняя цена: {mean_price:.2f}", color='red', fontsize=13, ha='center')
plt.figtext(0.49, 0.56, f"Медианная цена: {median_price:.2f}", color='purple', fontsize=13, ha='center')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\730647897.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data= data_filter, x = 'Площадь', y = 'Цена', palette='pastel')

# %%
plt.figure(figsize=(16,8))
sns.set_style("whitegrid")
sns.boxplot(data= data_filter, x = 'Площадь', palette='pastel')
# Out:
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\118700952.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data= data_filter, x = 'Площадь', palette='pastel')
# <Axes: xlabel='Площадь'>

# %%
plt.figure(figsize=(16,8))
sns.set_style("whitegrid")
sns.boxplot(data= data_filter, x = 'Цена', palette='pastel')
# Out:
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\4257936927.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data= data_filter, x = 'Цена', palette='pastel')
# <Axes: xlabel='Цена'>

# %% [markdown]
# ### Cтандартизация

# %%
#Cоздаем датафрейм для стандартизации где нет данных которые нельзя стандартизировать 
df_s = df_Rostov.drop(columns=['Дата публикации', 'Район', 'Улица', 'Номер дома'])

# %%
# Производим логарифмирование данных для их сглаживания
list = ['Площадь', "Просмотров", 'Цена']
df_s[list] = np.log1p(df_s[list])

# %%
#Cтандартизация
scaler = RobustScaler()

df_scaler = scaler.fit_transform(df_s)
df_scaler = pd.DataFrame(df_scaler, columns= df_s.columns)

# %%
plt.figure(figsize=(16,8))
sns.set_style("whitegrid")
sns.boxplot(data= df_scaler , x = 'Цена', palette='pastel')
# Out:
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\1420948107.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data= df_scaler , x = 'Цена', palette='pastel')
# <Axes: xlabel='Цена'>

# %%
plt.figure(figsize=(16,8))
sns.set_style("whitegrid")
sns.boxplot(data= df_scaler , x = 'Площадь', palette='pastel')
# Out:
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\1975042520.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data= df_scaler , x = 'Площадь', palette='pastel')
# <Axes: xlabel='Площадь'>

# %%
plt.figure(figsize=(16,8))
sns.set_style("whitegrid")
sns.histplot(data= df_scaler , x = 'Цена', palette='pastel', kde = True)
plt.show()
# Out:
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\2493459497.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data= df_scaler , x = 'Цена', palette='pastel', kde = True)

# %%
plt.figure(figsize=(16,8))
sns.set_style("whitegrid")
sns.histplot(data= df_scaler , x = 'Площадь', palette='pastel', kde = True)
plt.show()
# Out:
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\1979936024.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data= df_scaler , x = 'Площадь', palette='pastel', kde = True)

# %%
plt.figure(figsize=(16,8))
sns.set_style("whitegrid")
sns.histplot(data= df_scaler , x = 'Просмотров', palette='pastel', kde = True)
plt.show()
# Out:
# C:\Users\Александр\AppData\Local\Temp\ipykernel_2344\3396517954.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data= df_scaler , x = 'Просмотров', palette='pastel', kde = True)

# %% [markdown]
# ### Разделение данных и обучение

# %%
#Разделение данных на тестовую и тренировочную выборку
x = df_scaler.drop(columns='Цена')
y = df_scaler['Цена']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_train, x_val, y_train, y_val  = train_test_split(x_train, y_train, test_size = 0.125, random_state=42)
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (518, 7)
# (74, 7)
# (148, 7)

# %%
# Первая модель для оценки работы с данными и результатами потерь
model = Sequential([
    layers.Dense(256, activation='relu', input_shape = (x_train.shape[1],)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(64, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(32, activation='relu'),
    
    layers.Dense(1)
])

model.compile(optimizer='adam', loss= 'mse', metrics=['mae'])

model.fit(x_train, y_train, epochs= 100, batch_size= 128, validation_data=(x_val, y_val))
# Out:
# C:\Users\Александр\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - loss: 0.8443 - mae: 1.2580 - val_loss: 0.3201 - val_mae: 0.6464
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6658 - mae: 1.0590 - val_loss: 0.3215 - val_mae: 0.6516
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.5061 - mae: 0.8857 - val_loss: 0.3183 - val_mae: 0.6477
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.4854 - mae: 0.8573 - val_loss: 0.3171 - val_mae: 0.6449
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4018 - mae: 0.7635 - val_loss: 0.3197 - val_mae: 0.6474
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4061 - mae: 0.7729 - val_loss: 0.3234 - val_mae: 0.6538
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3397 - mae: 0.6864 - val_loss: 0.3270 - val_mae: 0.6630
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3159 - mae: 0.6588 - val_loss: 0.3304 - val_mae: 0.6718
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3360 - mae: 0.6936 - val_loss: 0.3332 - val_mae: 0.6789
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3165 - mae: 0.6402 - val_loss: 0.3346 - val_mae: 0.6834
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3430 - mae: 0.6923 - val_loss: 0.3343 - val_mae: 0.6856
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.3223 - mae: 0.6579 - val_loss: 0.3318 - val_mae: 0.6834
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2064 - mae: 0.5091 - val_loss: 0.2199 - val_mae: 0.5417
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1722 - mae: 0.4665 - val_loss: 0.2130 - val_mae: 0.5333
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2026 - mae: 0.5161 - val_loss: 0.2097 - val_mae: 0.5297
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1905 - mae: 0.4817 - val_loss: 0.2107 - val_mae: 0.5338
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1970 - mae: 0.5076 - val_loss: 0.2114 - val_mae: 0.5360
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2055 - mae: 0.5055 - val_loss: 0.2130 - val_mae: 0.5398
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1996 - mae: 0.4998 - val_loss: 0.2123 - val_mae: 0.5381
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1846 - mae: 0.4777 - val_loss: 0.2069 - val_mae: 0.5262

# %%
# Модель 2 с ручным подбором слоев и параметров
model2 = Sequential([
    layers.Dense(256, activation='relu', input_shape = (x_train.shape[1],)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(64, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(32, activation='relu'),
    
    layers.Dense(1)
])

model2.compile(optimizer='adam', loss= 'mse', metrics=['mae'])

model2.fit(x_train, y_train, epochs= 100, batch_size= 128, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# C:\Users\Александр\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 162ms/step - loss: 1.0262 - mae: 1.4496 - val_loss: 0.3287 - val_mae: 0.6649
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.7644 - mae: 1.1722 - val_loss: 0.3211 - val_mae: 0.6556
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.5586 - mae: 0.9544 - val_loss: 0.3184 - val_mae: 0.6496
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4904 - mae: 0.8611 - val_loss: 0.3185 - val_mae: 0.6471
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4558 - mae: 0.8205 - val_loss: 0.3200 - val_mae: 0.6469
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.4019 - mae: 0.7608 - val_loss: 0.3221 - val_mae: 0.6476
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3775 - mae: 0.7328 - val_loss: 0.3246 - val_mae: 0.6503
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3763 - mae: 0.7318 - val_loss: 0.3277 - val_mae: 0.6539
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3744 - mae: 0.7314 - val_loss: 0.3302 - val_mae: 0.6571
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3579 - mae: 0.7211 - val_loss: 0.3320 - val_mae: 0.6590
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.3570 - mae: 0.7072 - val_loss: 0.3338 - val_mae: 0.6608
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.3418 - mae: 0.6852 - val_loss: 0.3337 - val_mae: 0.6615
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3179 - mae: 0.6709 - val_loss: 0.3291 - val_mae: 0.6577
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3187 - mae: 0.6636 - val_loss: 0.3272 - val_mae: 0.6573
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3153 - mae: 0.6625 - val_loss: 0.3258 - val_mae: 0.6558
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2925 - mae: 0.6270 - val_loss: 0.3236 - val_mae: 0.6530
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2725 - mae: 0.6072 - val_loss: 0.3206 - val_mae: 0.6493
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.2791 - mae: 0.6084 - val_loss: 0.3187 - val_mae: 0.6464
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2850 - mae: 0.6192 - val_loss: 0.3155 - val_mae: 0.6414
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3043 - mae: 0.6419 - val_loss: 0.3152 - val_mae: 0.6406
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3086 - mae: 0.6521 - val_loss: 0.3153 - val_mae: 0.6405
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2968 - mae: 0.6331 - val_loss: 0.3120 - val_mae: 0.6368
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2825 - mae: 0.6166 - val_loss: 0.3095 - val_mae: 0.6341
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2756 - mae: 0.6072 - val_loss: 0.3050 - val_mae: 0.6294
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.2632 - mae: 0.5864 - val_loss: 0.3025 - val_mae: 0.6268
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2893 - mae: 0.6291 - val_loss: 0.3019 - val_mae: 0.6268
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2074 - mae: 0.5226 - val_loss: 0.2539 - val_mae: 0.5707
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2287 - mae: 0.5334 - val_loss: 0.2503 - val_mae: 0.5649
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2021 - mae: 0.5099 - val_loss: 0.2388 - val_mae: 0.5479
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2255 - mae: 0.5367 - val_loss: 0.2286 - val_mae: 0.5317
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2106 - mae: 0.5181 - val_loss: 0.2254 - val_mae: 0.5293
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2018 - mae: 0.5116 - val_loss: 0.2295 - val_mae: 0.5385
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2069 - mae: 0.5112 - val_loss: 0.2317 - val_mae: 0.5457
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2064 - mae: 0.5135 - val_loss: 0.2318 - val_mae: 0.5508
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1904 - mae: 0.4886 - val_loss: 0.2294 - val_mae: 0.5502
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2030 - mae: 0.5212 - val_loss: 0.2275 - val_mae: 0.5505
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2096 - mae: 0.5304 - val_loss: 0.2253 - val_mae: 0.5478
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2293 - mae: 0.5327 - val_loss: 0.2242 - val_mae: 0.5439
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2149 - mae: 0.5251 - val_loss: 0.2255 - val_mae: 0.5433
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1905 - mae: 0.4919 - val_loss: 0.2266 - val_mae: 0.5450
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2110 - mae: 0.5048 - val_loss: 0.2195 - val_mae: 0.5393
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2009 - mae: 0.5012 - val_loss: 0.2171 - val_mae: 0.5384
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1892 - mae: 0.4857 - val_loss: 0.2145 - val_mae: 0.5341
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1969 - mae: 0.5032 - val_loss: 0.2161 - val_mae: 0.5355
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2261 - mae: 0.5446 - val_loss: 0.2181 - val_mae: 0.5378
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2002 - mae: 0.5097 - val_loss: 0.2195 - val_mae: 0.5394
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1805 - mae: 0.4856 - val_loss: 0.2139 - val_mae: 0.5311
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1861 - mae: 0.4858 - val_loss: 0.1995 - val_mae: 0.5169
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2028 - mae: 0.5009 - val_loss: 0.1945 - val_mae: 0.5158
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1980 - mae: 0.4917 - val_loss: 0.1921 - val_mae: 0.5132
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2115 - mae: 0.5153 - val_loss: 0.1916 - val_mae: 0.5093
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1920 - mae: 0.5012 - val_loss: 0.1915 - val_mae: 0.5049
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2150 - mae: 0.5262 - val_loss: 0.1895 - val_mae: 0.4999
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2022 - mae: 0.5042 - val_loss: 0.1834 - val_mae: 0.4969
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2104 - mae: 0.5183 - val_loss: 0.1822 - val_mae: 0.4979
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2037 - mae: 0.5071 - val_loss: 0.1844 - val_mae: 0.5025
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1893 - mae: 0.4910 - val_loss: 0.1828 - val_mae: 0.4966
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1799 - mae: 0.4845 - val_loss: 0.1771 - val_mae: 0.4908
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1868 - mae: 0.4934 - val_loss: 0.1771 - val_mae: 0.4910
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1966 - mae: 0.5017 - val_loss: 0.1792 - val_mae: 0.4884

# %%
# Функция создания модели
def create_model(optimizer='adam', activation='relu', neurons=128):
    model_r_s = Sequential([
    layers.Dense(units = neurons, activation=activation, input_shape = (x_train.shape[1],), 
                 kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)),
    layers.BatchNormalization(),

    layers.Dense(units = int(neurons/2), activation='relu'),
    
    layers.Dense(1, activation = None)
    ])
    model_r_s.compile(optimizer = optimizer, loss = 'mse', metrics = ['mae'])
    return model_r_s

# %%
# Нахождение оптимальных гипрепараметров с помощью KerasRegressor
param_dist = {
    'optimizer': ['Adam', 'sgd', 'rmsprop'],
    'activation': ['relu', 'tanh', 'sigmoid'],
    'neurons': [64, 128, 256],
    'batch_size': [8, 16, 32],
    'epochs': [30, 100, 200],
    'random_state': [42, None, 33]
}

model_r_s = KerasRegressor(build_fn=create_model, verbose=0, neurons=128, optimizer='adam', activation='relu')

rand_serch = RandomizedSearchCV(
    estimator = model_r_s,
    param_distributions = param_dist, 
    n_iter= 10, cv =3, verbose=2, random_state=42)

rand_serch_result = rand_serch.fit(x_train, y_train)

# %%
print("Лучшие параметры:", rand_serch_result.best_params_, '\n')
print("Лучшая модель:", rand_serch_result.best_estimator_, '\n')
print("Лучшее значение на кросс-валидации:", rand_serch_result.best_score_, '\n')

best_param = rand_serch_result.best_params_
# Out:
# Лучшие параметры: {'random_state': None, 'optimizer': 'sgd', 'neurons': 64, 'epochs': 100, 'batch_size': 16, 'activation': 'tanh'}
#
# Лучшая модель: KerasRegressor(
# 	model=None
# 	build_fn=<function create_model at 0x000001EC58C8B9A0>
# 	warm_start=False
# 	random_state=None
# 	optimizer=sgd
# 	loss=None
# 	metrics=None
# 	batch_size=16
# 	validation_batch_size=None
# 	verbose=0
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=100
# 	neurons=64
# 	activation=tanh
# )
#
# Лучшее значение на кросс-валидации: 0.3952543465628307

# %%
# Создадим модель на основе расчета гипрепараметров
model3 = Sequential([
    layers.Dense(units=best_param['neurons'], input_shape = (x_train.shape[1],), activation= best_param['activation'],
                 kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)),
    layers.BatchNormalization(),

    layers.Dense(units = int(best_param['neurons']/2), activation= best_param['activation']),
    #layers.BatchNormalization(),

    #layers.Dense(units = int(best_param['neurons']/4), activation= best_param['activation']),
    
    layers.Dense(1, activation= None)
])


model3.compile(optimizer=best_param['optimizer'], loss='mse', metrics=['mae'])

model3.fit(x_train, y_train, batch_size= best_param['batch_size'], 
           epochs= best_param['epochs'], validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.7883 - mae: 0.6868 - val_loss: 0.5959 - val_mae: 0.5871
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5811 - mae: 0.5855 - val_loss: 0.7175 - val_mae: 0.6420
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4841 - mae: 0.5379 - val_loss: 0.6271 - val_mae: 0.6370
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3926 - mae: 0.5005 - val_loss: 0.5092 - val_mae: 0.5499
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4419 - mae: 0.5194 - val_loss: 0.9451 - val_mae: 0.7752
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4697 - mae: 0.5318 - val_loss: 0.4327 - val_mae: 0.5329
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4875 - mae: 0.5350 - val_loss: 0.4257 - val_mae: 0.5192
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4250 - mae: 0.5108 - val_loss: 0.4790 - val_mae: 0.5380
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4104 - mae: 0.4994 - val_loss: 0.5065 - val_mae: 0.5658
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3686 - mae: 0.4785 - val_loss: 0.3802 - val_mae: 0.4845
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4440 - mae: 0.5288 - val_loss: 0.4125 - val_mae: 0.5066
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3983 - mae: 0.4815 - val_loss: 0.4320 - val_mae: 0.5092
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3953 - mae: 0.4790 - val_loss: 0.4498 - val_mae: 0.5240
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.
100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3354 - mae: 0.4408 - val_loss: 0.3760 - val_mae: 0.4816
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3060 - mae: 0.4435 - val_loss: 0.3874 - val_mae: 0.4984
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3423 - mae: 0.4393 - val_loss: 0.3916 - val_mae: 0.4972
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3306 - mae: 0.4521 - val_loss: 0.4652 - val_mae: 0.5420
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3850 - mae: 0.4723 - val_loss: 0.3825 - val_mae: 0.4844
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3861 - mae: 0.4903 - val_loss: 0.3337 - val_mae: 0.4602
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3125 - mae: 0.4351 - val_loss: 0.3310 - val_mae: 0.4573
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3230 - mae: 0.4569 - val_loss: 0.3989 - val_mae: 0.5037
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3189 - mae: 0.4352 - val_loss: 0.3853 - val_mae: 0.4825

# %%
# Визуализауия моделей предсказания и валидационных данных
y_pred3 = model3.predict(x_val)
y_pred2 = model2.predict(x_val)
y_pred1 = model.predict(x_val)

plt.figure(figsize=(16, 8))

sns.kdeplot(y_val, color='blue', label='Data', lw=2)
sns.kdeplot(y_pred3.flatten(), color='red', label='Model 3 (KDE)', lw=2)
sns.kdeplot(y_pred2.flatten(), color='green', label='Model 2 (KDE)', lw=2)
sns.kdeplot(y_pred1.flatten(), color='violet', label='Model 1 (KDE)', lw=2)

plt.xlabel('Реальные данные (y_val)')
plt.ylabel('Предсказания моделей (y_pred)')
plt.title('Сравнение реальных данных и предсказаний моделей с KDE')
plt.legend()

plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step

# %%
# Вычислим среднеквадратичную ошибку, абсолюдную ошибку, коэф. детерминации /
mae = mean_absolute_error(y_val, y_pred3)
mse = mean_squared_error(y_val, y_pred3)
r2 = r2_score(y_val, y_pred3)

print (f"MAE {mae:.2} \n", f"MSE {mse:.2} \n", f"R2 {r2:.2} \n")
# Out:
# MAE 0.48
#  MSE 0.38
#  R2 0.51

# %%
y_pred_test_3 = model3.predict(x_test)
y_pred_test_2 = model2.predict(x_test)
y_pred_test_1 = model.predict(x_test)

plt.figure(figsize=(16, 8))

sns.kdeplot(y_val, color='blue', label='Data', lw=2)
sns.kdeplot(y_pred3.flatten(), color='red', label='Model 3 (KDE)', lw=2)
sns.kdeplot(y_pred2.flatten(), color='green', label='Model 2 (KDE)', lw=2)
sns.kdeplot(y_pred1.flatten(), color='violet', label='Model 1 (KDE)', lw=2)

plt.xlabel('Реальные данные (y_val)')
plt.ylabel('Предсказания моделей (y_pred)')
plt.title('Сравнение реальных данных и предсказаний моделей с KDE')
plt.legend()

plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
# Вычислим среднеквадратичную ошибку, абсолюдную ошибку, коэф. детерминации /
mae = mean_absolute_error(y_test, y_pred_test_3)
mse = mean_squared_error(y_test, y_pred_test_3)
r2 = r2_score(y_test, y_pred_test_3)

print (f"MAE {mae:.2} \n", f"MSE {mse:.2} \n", f"R2 {r2:.2} \n")
# Out:
# MAE 0.47
#  MSE 0.39
#  R2 0.43

# %% [markdown]
# ### Конвертация модели (Сохранение и загрузка)

# %%
#Сериализация
model3.save('mlp_model3.h5')
